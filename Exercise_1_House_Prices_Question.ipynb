# %% [markdown]
# <a href="https://colab.research.google.com/github/MachineLearning-Nerd/DeepLearning-Tensorflow/blob/master/Exercise_1_House_Prices_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
xs = np.array([0, 1, 2, 3, 4, 5, 6], dtype = float)
ys = np.array([0.5, 1, 1.5, 2, 2.5, 3, 3.5 ], dtype = float)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0709 06:53:28.021690 140104130795392 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.fit(xs,ys,epochs = 500)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 0s 13ms/sample - loss: 12.6586
# Epoch 2/500
# 7/7 [==============================] - 0s 967us/sample - loss: 6.6801
# Epoch 3/500
# 7/7 [==============================] - 0s 725us/sample - loss: 3.5303
# Epoch 4/500
# 7/7 [==============================] - 0s 244us/sample - loss: 1.8707
# Epoch 5/500
# 7/7 [==============================] - 0s 318us/sample - loss: 0.9963
# Epoch 6/500
# 7/7 [==============================] - 0s 285us/sample - loss: 0.5355
# Epoch 7/500
# 7/7 [==============================] - 0s 318us/sample - loss: 0.2926
# Epoch 8/500
# 7/7 [==============================] - 0s 269us/sample - loss: 0.1645
# Epoch 9/500
# 7/7 [==============================] - 0s 237us/sample - loss: 0.0969
# Epoch 10/500
# 7/7 [==============================] - 0s 448us/sample - loss: 0.0612
# Epoch 11/500
# 7/7 [==============================] - 0s 480us/sample - loss: 0.0422
# Epoch 12/500
# ...

# %%
print(model.predict([7.0]))
# Out:
# [[4.0097694]]
